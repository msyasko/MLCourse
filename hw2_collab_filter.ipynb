# %%
import numpy as np
from scipy.sparse import lil_matrix, csr_matrix 
from tqdm import tqdm
import time

# %%
def h(x, w0, w, v):
    summ = 0
    n = x.shape[0]
    
    for f in range(v.shape[1]):
        summ += (x.dot(v[:,f]))**2 - (x.multiply(x)).dot(v[:,f]**2)

    return w0 + x.dot(w) + 0.5 * summ[0]

# %%
def MSE(y_true, y_pred):
    return np.sum((y_true - y_pred) ** 2) / float(y_true.shape[0])

def RMSE(y_true, y_pred):
    return np.sqrt(MSE(y_true, y_pred))

def R2(y_true, y_pred):
    return 1. - MSE(y_true, y_pred) / MSE(y_true, np.mean(y_true) * np.ones(shape=y_true.shape))

# %%
# Сбор данных

col_ids = []
row_ids = []
y = []

with open('./netflix-prize-data/combined_data_1.txt', 'r') as f:    
    counter = 0
    for line in tqdm(f): 
        if ':' in line:
            film_id = int(line[:-2])
        else:
            values = line.split(',')
            user_id = int(values[0])
            rating = int(values[1])
            
            row_ids.append(counter)
            col_ids.append(user_id)
            
            row_ids.append(counter)
            col_ids.append(film_id)

            y.append(rating)
            counter += 1


    values = np.ones(len(row_ids))
    x = csr_matrix((values, (row_ids, col_ids)), dtype=np.float32)
    y = np.array(y, dtype=np.float32)
# Out:
# 24058263it [01:14, 324503.91it/s]

# %%
def H(X, w0, w, v):
    x_x = X.multiply(X)
    x_v = X.dot(v)
    x_v_2 = np.multiply(x_v, x_v)
    x_w = X.dot(w.transpose())
    
    v_v = np.multiply(v, v)
    xx_vv = x_x.dot(v_v)
    
    result = w0 + x_w + 0.5 * np.ravel(np.sum(x_v_2 - xx_vv, axis = 1))
    return result

# %%
def dL_dw0(X, w0, w, v, delta):
    return -2. * np.sum(delta) / float(X.shape[0])

# %%
def dL_dwi(X, w0, w, v, delta):
    return -2. * np.ravel(np.sum(delta.multiply(X), axis = 0)) / float(X.shape[0])

# %%
def dL_dv(X, w0, w, v, delta):
    x_x = X.multiply(X)
    x_v = X.dot(v)
    dx = (delta.multiply(X)).transpose()
    xx_v = dx.dot(x_v)
    
    dxx = np.sum(delta.multiply(x_x), axis = 0)
    vdxx = (v.T * np.ravel(dxx)).T

    return -2. * (xx_v - vdxx)

# %%
def gradDesc(X, y, X_test, y_test):
    w0 = 0
    
    k = 3
    n_iter = 1000
    stepsize = 0.01
    stepsize_v = 0.002
    w = np.random.normal(0, 0.1, X.shape[1])
    v = np.random.normal(0, 0.001, size = (X.shape[1], k))

    for i in range(n_iter):
        last_time = time.time()
        idxs = np.random.choice(range(X.shape[0]), size=200000, replace=False)
        X_s = X[idxs]
        y_s = y[idxs]
        
        y_pred = H(X_s, w0, w, v)

        delta = csr_matrix(y_s - y_pred, dtype = np.float32).transpose()

        grad_w0 = stepsize * dL_dw0(X_s, w0, w, v, delta)
        grad_w = stepsize * dL_dwi(X_s, w0, w, v, delta)
        grad_v = stepsize_v * dL_dv(X_s, w0, w, v, delta)

        if i % 10 == 0:
            iter_time = time.time() - last_time
            print('%d: RMSE(train) = %.5f RMSE(test) = %.5f iter_time = %.5f' % (
                i,
                RMSE(y, H(X, w0, w, v)), 
                RMSE(y_test, H(X_test, w0, w, v)),
                iter_time
            ))
            
        w0 = w0 - grad_w0
        w = w - grad_w
        v = v - grad_v
        
    return w0, w, v


def CV(X, y, n_folds):
    fold_indexes = np.random.randint(0, n_folds, X.shape[0])
    
    metr = []
    
    folds = []
    for i in range(n_folds):
        indexes = np.where(fold_indexes == i)
        x_slice = X[indexes]
        y_slice = y[indexes]
        
        indexes = np.where(fold_indexes != i)
        x_not_slice = X[indexes]
        y_not_slice = y[indexes]
        
        folds.append((x_slice, y_slice, x_not_slice, y_not_slice))
        
    for i in range(n_folds):
        x_val = folds[i][0]
        y_val = folds[i][1]
        x_learn = folds[i][2]
        y_learn = folds[i][3]
        
        w0, w, v = gradDesc(x_learn, y_learn, x_val, y_val)
        
        y_pr = H(x_val, w0, w, v)
        
        rm = R2(y_val, y_pr)
        metr.append(rm)
        print('fold index ' + str(i) + ': R2 = ' + str(rm))
    
    return metr

# %%
CV(x, y, 5)
# Out:
# 0: RMSE(train) = 3.75992 RMSE(test) = 3.76010 iter_time = 3.50956
# 10: RMSE(train) = 3.13502 RMSE(test) = 3.13520 iter_time = 3.48985
# 20: RMSE(train) = 2.63713 RMSE(test) = 2.63731 iter_time = 3.51102
# 30: RMSE(train) = 2.24430 RMSE(test) = 2.24448 iter_time = 3.41701
# 40: RMSE(train) = 1.93736 RMSE(test) = 1.93756 iter_time = 3.49569
# 50: RMSE(train) = 1.69113 RMSE(test) = 1.69174 iter_time = 3.50101
# 60: RMSE(train) = 1.44694 RMSE(test) = 1.44992 iter_time = 3.48766
# 70: RMSE(train) = 1.22663 RMSE(test) = 1.23288 iter_time = 3.50187
# 80: RMSE(train) = 1.12916 RMSE(test) = 1.13804 iter_time = 3.50488
# 90: RMSE(train) = 1.08095 RMSE(test) = 1.09094 iter_time = 3.49745
# 100: RMSE(train) = 1.05351 RMSE(test) = 1.06433 iter_time = 3.45136
# 110: RMSE(train) = 1.03525 RMSE(test) = 1.04654 iter_time = 3.48526
# 120: RMSE(train) = 1.02284 RMSE(test) = 1.03477 iter_time = 3.46685
# 130: RMSE(train) = 1.01373 RMSE(test) = 1.02594 iter_time = 3.50586
# 140: RMSE(train) = 1.00676 RMSE(test) = 1.01925 iter_time = 3.50642
# 150: RMSE(train) = 1.00119 RMSE(test) = 1.01414 iter_time = 3.49734
# 160: RMSE(train) = 0.99670 RMSE(test) = 1.00991 iter_time = 3.51520
# 170: RMSE(train) = 0.99308 RMSE(test) = 1.00657 iter_time = 3.43611
# 180: RMSE(train) = 0.99006 RMSE(test) = 1.00383 iter_time = 3.49821
# 190: RMSE(train) = 0.98752 RMSE(test) = 1.00150 iter_time = 3.49972
# 200: RMSE(train) = 0.98523 RMSE(test) = 0.99957 iter_time = 3.49609
# 210: RMSE(train) = 0.98333 RMSE(test) = 0.99784 iter_time = 3.51542
# 220: RMSE(train) = 0.98171 RMSE(test) = 0.99642 iter_time = 3.49045
# 230: RMSE(train) = 0.98011 RMSE(test) = 0.99503 iter_time = 3.50130
# 240: RMSE(train) = 0.97868 RMSE(test) = 0.99372 iter_time = 3.48792
# 250: RMSE(train) = 0.97743 RMSE(test) = 0.99270 iter_time = 3.41047
# 260: RMSE(train) = 0.97617 RMSE(test) = 0.99159 iter_time = 3.49784
# 270: RMSE(train) = 0.97515 RMSE(test) = 0.99063 iter_time = 3.47121
# 280: RMSE(train) = 0.97406 RMSE(test) = 0.98983 iter_time = 3.52950
# 290: RMSE(train) = 0.97285 RMSE(test) = 0.98882 iter_time = 3.50258
# 300: RMSE(train) = 0.97187 RMSE(test) = 0.98804 iter_time = 3.50961
# 310: RMSE(train) = 0.97039 RMSE(test) = 0.98682 iter_time = 3.52984
# 320: RMSE(train) = 0.96890 RMSE(test) = 0.98553 iter_time = 3.46938
# 330: RMSE(train) = 0.96682 RMSE(test) = 0.98401 iter_time = 3.50883
# 340: RMSE(train) = 0.96431 RMSE(test) = 0.98207 iter_time = 3.50081
# 350: RMSE(train) = 0.96124 RMSE(test) = 0.97974 iter_time = 3.50723
# 360: RMSE(train) = 0.95729 RMSE(test) = 0.97661 iter_time = 3.37787
# 370: RMSE(train) = 0.95301 RMSE(test) = 0.97343 iter_time = 3.50044
# 380: RMSE(train) = 0.94872 RMSE(test) = 0.97044 iter_time = 3.50721
# 390: RMSE(train) = 0.94467 RMSE(test) = 0.96766 iter_time = 3.52642
# 400: RMSE(train) = 0.94119 RMSE(test) = 0.96543 iter_time = 3.45995
# 410: RMSE(train) = 0.93791 RMSE(test) = 0.96332 iter_time = 3.47151
# 420: RMSE(train) = 0.93503 RMSE(test) = 0.96148 iter_time = 3.52200
# 430: RMSE(train) = 0.93225 RMSE(test) = 0.95983 iter_time = 3.49954
# 440: RMSE(train) = 0.92963 RMSE(test) = 0.95806 iter_time = 3.48279
# 450: RMSE(train) = 0.92719 RMSE(test) = 0.95657 iter_time = 3.50449
# 460: RMSE(train) = 0.92489 RMSE(test) = 0.95510 iter_time = 3.52010
# 470: RMSE(train) = 0.92272 RMSE(test) = 0.95384 iter_time = 3.50268
# 480: RMSE(train) = 0.92072 RMSE(test) = 0.95272 iter_time = 3.44200
# 490: RMSE(train) = 0.91888 RMSE(test) = 0.95176 iter_time = 3.52303
# 500: RMSE(train) = 0.91712 RMSE(test) = 0.95074 iter_time = 3.49793
# 510: RMSE(train) = 0.91554 RMSE(test) = 0.94996 iter_time = 3.48660
# 520: RMSE(train) = 0.91411 RMSE(test) = 0.94921 iter_time = 3.51508
# 530: RMSE(train) = 0.91273 RMSE(test) = 0.94826 iter_time = 3.50544
# 540: RMSE(train) = 0.91140 RMSE(test) = 0.94764 iter_time = 3.50003
# 550: RMSE(train) = 0.91020 RMSE(test) = 0.94700 iter_time = 3.41496
# 910: RMSE(train) = 0.88795 RMSE(test) = 0.93415 iter_time = 3.58279
# 920: RMSE(train) = 0.88762 RMSE(test) = 0.93382 iter_time = 3.48656
# 930: RMSE(train) = 0.88729 RMSE(test) = 0.93362 iter_time = 3.50890
# 940: RMSE(train) = 0.88697 RMSE(test) = 0.93356 iter_time = 3.52717
# 950: RMSE(train) = 0.88658 RMSE(test) = 0.93332 iter_time = 3.52468
# 960: RMSE(train) = 0.88628 RMSE(test) = 0.93317 iter_time = 3.52511
# 970: RMSE(train) = 0.88592 RMSE(test) = 0.93309 iter_time = 3.52538
# 980: RMSE(train) = 0.88561 RMSE(test) = 0.93289 iter_time = 3.52645
# 990: RMSE(train) = 0.88537 RMSE(test) = 0.93278 iter_time = 3.50827
# fold index 0: R2 = 0.2631461910207641
# 0: RMSE(train) = 3.75769 RMSE(test) = 3.75791 iter_time = 3.50070
# 10: RMSE(train) = 3.13312 RMSE(test) = 3.13336 iter_time = 3.51403
# 20: RMSE(train) = 2.63540 RMSE(test) = 2.63564 iter_time = 3.51333
# 30: RMSE(train) = 2.24302 RMSE(test) = 2.24329 iter_time = 3.45047
# 40: RMSE(train) = 1.93743 RMSE(test) = 1.93772 iter_time = 3.52396
# 50: RMSE(train) = 1.70058 RMSE(test) = 1.70098 iter_time = 3.51936
# 60: RMSE(train) = 1.50322 RMSE(test) = 1.50441 iter_time = 3.39238
# 70: RMSE(train) = 1.30199 RMSE(test) = 1.30593 iter_time = 3.46303
# 80: RMSE(train) = 1.15663 RMSE(test) = 1.16366 iter_time = 3.52178
# 90: RMSE(train) = 1.09331 RMSE(test) = 1.10303 iter_time = 3.50986
# 100: RMSE(train) = 1.06024 RMSE(test) = 1.07126 iter_time = 3.53472
# 110: RMSE(train) = 1.03999 RMSE(test) = 1.05187 iter_time = 3.51702
# 120: RMSE(train) = 1.02650 RMSE(test) = 1.03888 iter_time = 3.54233
# 130: RMSE(train) = 1.01711 RMSE(test) = 1.02984 iter_time = 3.52663
# 140: RMSE(train) = 1.01022 RMSE(test) = 1.02337 iter_time = 3.51529
# 150: RMSE(train) = 1.00459 RMSE(test) = 1.01807 iter_time = 3.48010
# 160: RMSE(train) = 1.00016 RMSE(test) = 1.01393 iter_time = 3.51289
# 170: RMSE(train) = 0.99654 RMSE(test) = 1.01060 iter_time = 3.52794
# 180: RMSE(train) = 0.99345 RMSE(test) = 1.00782 iter_time = 3.51755
# 190: RMSE(train) = 0.99085 RMSE(test) = 1.00542 iter_time = 3.46817
# 200: RMSE(train) = 0.98857 RMSE(test) = 1.00333 iter_time = 3.38123
# 210: RMSE(train) = 0.98655 RMSE(test) = 1.00146 iter_time = 3.50887
# 220: RMSE(train) = 0.98456 RMSE(test) = 0.99971 iter_time = 3.53314
# 230: RMSE(train) = 0.98275 RMSE(test) = 0.99822 iter_time = 3.44889
# 240: RMSE(train) = 0.98082 RMSE(test) = 0.99660 iter_time = 3.51441
# 250: RMSE(train) = 0.97881 RMSE(test) = 0.99486 iter_time = 3.53573
# 260: RMSE(train) = 0.97638 RMSE(test) = 0.99277 iter_time = 3.44319
# 270: RMSE(train) = 0.97347 RMSE(test) = 0.99053 iter_time = 3.51948
# 280: RMSE(train) = 0.97000 RMSE(test) = 0.98775 iter_time = 3.48777
# 290: RMSE(train) = 0.96588 RMSE(test) = 0.98459 iter_time = 3.52554
# 300: RMSE(train) = 0.96130 RMSE(test) = 0.98104 iter_time = 3.45890
# 310: RMSE(train) = 0.95664 RMSE(test) = 0.97763 iter_time = 3.52472
# 320: RMSE(train) = 0.95252 RMSE(test) = 0.97467 iter_time = 3.51424
# 330: RMSE(train) = 0.94881 RMSE(test) = 0.97196 iter_time = 3.52964
# 340: RMSE(train) = 0.94569 RMSE(test) = 0.96981 iter_time = 3.52128
# 350: RMSE(train) = 0.94284 RMSE(test) = 0.96785 iter_time = 3.52215
# 360: RMSE(train) = 0.94029 RMSE(test) = 0.96588 iter_time = 3.51743
# 370: RMSE(train) = 0.93787 RMSE(test) = 0.96420 iter_time = 3.36146
# 380: RMSE(train) = 0.93568 RMSE(test) = 0.96257 iter_time = 3.53056
# 390: RMSE(train) = 0.93357 RMSE(test) = 0.96098 iter_time = 3.47514
# 400: RMSE(train) = 0.93161 RMSE(test) = 0.95956 iter_time = 3.53675
# 410: RMSE(train) = 0.92960 RMSE(test) = 0.95813 iter_time = 3.51672
# 420: RMSE(train) = 0.92772 RMSE(test) = 0.95671 iter_time = 3.51557
# 430: RMSE(train) = 0.92594 RMSE(test) = 0.95545 iter_time = 3.50871
# 440: RMSE(train) = 0.92400 RMSE(test) = 0.95401 iter_time = 3.59001
# 450: RMSE(train) = 0.92204 RMSE(test) = 0.95269 iter_time = 3.51443
# 460: RMSE(train) = 0.92017 RMSE(test) = 0.95136 iter_time = 3.52147
# 470: RMSE(train) = 0.91822 RMSE(test) = 0.95019 iter_time = 3.51283
# 480: RMSE(train) = 0.91625 RMSE(test) = 0.94905 iter_time = 3.54478
# 490: RMSE(train) = 0.91436 RMSE(test) = 0.94795 iter_time = 3.53536
# 500: RMSE(train) = 0.91258 RMSE(test) = 0.94706 iter_time = 3.51944
# 510: RMSE(train) = 0.91090 RMSE(test) = 0.94613 iter_time = 3.55321
# 520: RMSE(train) = 0.90920 RMSE(test) = 0.94532 iter_time = 3.52124
# 530: RMSE(train) = 0.90764 RMSE(test) = 0.94439 iter_time = 3.52275
# 540: RMSE(train) = 0.90613 RMSE(test) = 0.94368 iter_time = 3.52514
# 550: RMSE(train) = 0.90475 RMSE(test) = 0.94303 iter_time = 3.59052
# 560: RMSE(train) = 0.90340 RMSE(test) = 0.94233 iter_time = 3.50111
# 570: RMSE(train) = 0.90204 RMSE(test) = 0.94150 iter_time = 3.39033
# 580: RMSE(train) = 0.90086 RMSE(test) = 0.94085 iter_time = 3.64032
# 590: RMSE(train) = 0.89969 RMSE(test) = 0.94008 iter_time = 3.51420
# 950: RMSE(train) = 0.87493 RMSE(test) = 0.92286 iter_time = 3.51290
# 960: RMSE(train) = 0.87454 RMSE(test) = 0.92257 iter_time = 3.60259
# 970: RMSE(train) = 0.87426 RMSE(test) = 0.92225 iter_time = 3.51138
# 980: RMSE(train) = 0.87386 RMSE(test) = 0.92226 iter_time = 3.49488
# 990: RMSE(train) = 0.87350 RMSE(test) = 0.92201 iter_time = 3.52306
# fold index 1: R2 = 0.28000941266604396
# 0: RMSE(train) = 3.76842 RMSE(test) = 3.76910 iter_time = 3.50476
# 10: RMSE(train) = 3.14180 RMSE(test) = 3.14243 iter_time = 3.50805
# 20: RMSE(train) = 2.64263 RMSE(test) = 2.64321 iter_time = 3.50809
# 30: RMSE(train) = 2.24858 RMSE(test) = 2.24909 iter_time = 3.40722
# 40: RMSE(train) = 1.94154 RMSE(test) = 1.94199 iter_time = 3.51038
# 50: RMSE(train) = 1.69982 RMSE(test) = 1.70039 iter_time = 3.51229
# 60: RMSE(train) = 1.47996 RMSE(test) = 1.48205 iter_time = 3.52015
# 70: RMSE(train) = 1.25570 RMSE(test) = 1.26221 iter_time = 3.51489
# 80: RMSE(train) = 1.13791 RMSE(test) = 1.14699 iter_time = 3.54831
# 90: RMSE(train) = 1.08477 RMSE(test) = 1.09508 iter_time = 3.52413
# 100: RMSE(train) = 1.05496 RMSE(test) = 1.06596 iter_time = 3.66495
# 110: RMSE(train) = 1.03633 RMSE(test) = 1.04836 iter_time = 3.52535
# 120: RMSE(train) = 1.02347 RMSE(test) = 1.03616 iter_time = 3.52301
# 130: RMSE(train) = 1.01428 RMSE(test) = 1.02729 iter_time = 3.51953
# 140: RMSE(train) = 1.00742 RMSE(test) = 1.02081 iter_time = 3.51996
# 150: RMSE(train) = 1.00198 RMSE(test) = 1.01563 iter_time = 3.54742
# 160: RMSE(train) = 0.99749 RMSE(test) = 1.01133 iter_time = 3.51861
# 170: RMSE(train) = 0.99386 RMSE(test) = 1.00813 iter_time = 3.50369
# 180: RMSE(train) = 0.99076 RMSE(test) = 1.00514 iter_time = 3.46550
# 190: RMSE(train) = 0.98810 RMSE(test) = 1.00283 iter_time = 3.57703
# 200: RMSE(train) = 0.98579 RMSE(test) = 1.00060 iter_time = 3.50930
# 210: RMSE(train) = 0.98361 RMSE(test) = 0.99883 iter_time = 3.51590
# 220: RMSE(train) = 0.98151 RMSE(test) = 0.99697 iter_time = 3.52842
# 230: RMSE(train) = 0.97937 RMSE(test) = 0.99505 iter_time = 3.51836
# 240: RMSE(train) = 0.97693 RMSE(test) = 0.99295 iter_time = 3.52425
# 250: RMSE(train) = 0.97406 RMSE(test) = 0.99055 iter_time = 3.53407
# 260: RMSE(train) = 0.97084 RMSE(test) = 0.98817 iter_time = 3.61073
# 270: RMSE(train) = 0.96680 RMSE(test) = 0.98495 iter_time = 3.52980
# 280: RMSE(train) = 0.96250 RMSE(test) = 0.98156 iter_time = 3.56417
# 640: RMSE(train) = 0.88943 RMSE(test) = 0.93219 iter_time = 3.52188
# 650: RMSE(train) = 0.88852 RMSE(test) = 0.93154 iter_time = 3.51411
# 660: RMSE(train) = 0.88775 RMSE(test) = 0.93085 iter_time = 3.56466
# 670: RMSE(train) = 0.88685 RMSE(test) = 0.93051 iter_time = 3.58158
# 680: RMSE(train) = 0.88611 RMSE(test) = 0.92994 iter_time = 3.52638
# 690: RMSE(train) = 0.88543 RMSE(test) = 0.92937 iter_time = 3.51765
# 700: RMSE(train) = 0.88477 RMSE(test) = 0.92888 iter_time = 3.56138
# 710: RMSE(train) = 0.88409 RMSE(test) = 0.92851 iter_time = 3.57485
# 720: RMSE(train) = 0.88339 RMSE(test) = 0.92793 iter_time = 3.51901
# 730: RMSE(train) = 0.88275 RMSE(test) = 0.92758 iter_time = 3.39769
# 740: RMSE(train) = 0.88218 RMSE(test) = 0.92722 iter_time = 3.52069
# 750: RMSE(train) = 0.88154 RMSE(test) = 0.92663 iter_time = 3.52090
# 760: RMSE(train) = 0.88093 RMSE(test) = 0.92628 iter_time = 3.52212
# 770: RMSE(train) = 0.88041 RMSE(test) = 0.92589 iter_time = 3.51535
# 780: RMSE(train) = 0.87993 RMSE(test) = 0.92569 iter_time = 3.58883
# 790: RMSE(train) = 0.87944 RMSE(test) = 0.92557 iter_time = 3.52334
# 800: RMSE(train) = 0.87890 RMSE(test) = 0.92524 iter_time = 3.59317
# 810: RMSE(train) = 0.87842 RMSE(test) = 0.92477 iter_time = 3.51014
# 820: RMSE(train) = 0.87793 RMSE(test) = 0.92442 iter_time = 3.52443
# 830: RMSE(train) = 0.87751 RMSE(test) = 0.92406 iter_time = 3.52506
# 840: RMSE(train) = 0.87708 RMSE(test) = 0.92378 iter_time = 3.51988
# 850: RMSE(train) = 0.87662 RMSE(test) = 0.92366 iter_time = 3.52014
# 860: RMSE(train) = 0.87620 RMSE(test) = 0.92339 iter_time = 3.47102
# 870: RMSE(train) = 0.87579 RMSE(test) = 0.92321 iter_time = 3.52674
# 880: RMSE(train) = 0.87539 RMSE(test) = 0.92275 iter_time = 3.51991
# 890: RMSE(train) = 0.87500 RMSE(test) = 0.92259 iter_time = 3.52093
# 900: RMSE(train) = 0.87460 RMSE(test) = 0.92225 iter_time = 3.47514
# 910: RMSE(train) = 0.87422 RMSE(test) = 0.92198 iter_time = 3.52544
# 920: RMSE(train) = 0.87392 RMSE(test) = 0.92178 iter_time = 3.49239
# 930: RMSE(train) = 0.87361 RMSE(test) = 0.92156 iter_time = 3.47685
# 940: RMSE(train) = 0.87319 RMSE(test) = 0.92129 iter_time = 3.53459
# 950: RMSE(train) = 0.87284 RMSE(test) = 0.92107 iter_time = 3.55206
# 960: RMSE(train) = 0.87255 RMSE(test) = 0.92103 iter_time = 3.51671
# 970: RMSE(train) = 0.87225 RMSE(test) = 0.92081 iter_time = 3.51559
# 980: RMSE(train) = 0.87193 RMSE(test) = 0.92062 iter_time = 3.52700
# 990: RMSE(train) = 0.87165 RMSE(test) = 0.92040 iter_time = 3.44580
# fold index 2: R2 = 0.2819908433318903
# 0: RMSE(train) = 3.77338 RMSE(test) = 3.77263 iter_time = 3.52622
# 10: RMSE(train) = 3.14631 RMSE(test) = 3.14556 iter_time = 3.52897
# 20: RMSE(train) = 2.64673 RMSE(test) = 2.64598 iter_time = 3.53080
# 30: RMSE(train) = 2.25267 RMSE(test) = 2.25193 iter_time = 3.53027
# 40: RMSE(train) = 1.94581 RMSE(test) = 1.94508 iter_time = 3.51091
# 50: RMSE(train) = 1.70885 RMSE(test) = 1.70820 iter_time = 3.52825
# 60: RMSE(train) = 1.51927 RMSE(test) = 1.51917 iter_time = 3.48239
# 70: RMSE(train) = 1.33498 RMSE(test) = 1.33748 iter_time = 3.55039
# 80: RMSE(train) = 1.17641 RMSE(test) = 1.18298 iter_time = 3.34047
# 90: RMSE(train) = 1.10190 RMSE(test) = 1.11026 iter_time = 3.52591
# 100: RMSE(train) = 1.06583 RMSE(test) = 1.07530 iter_time = 3.52474
# 110: RMSE(train) = 1.04431 RMSE(test) = 1.05466 iter_time = 3.53017
# 120: RMSE(train) = 1.03034 RMSE(test) = 1.04123 iter_time = 3.52337
# 130: RMSE(train) = 1.02046 RMSE(test) = 1.03201 iter_time = 3.46250
# 140: RMSE(train) = 1.01298 RMSE(test) = 1.02491 iter_time = 3.54658
# 150: RMSE(train) = 1.00750 RMSE(test) = 1.01985 iter_time = 3.44806
# 160: RMSE(train) = 1.00285 RMSE(test) = 1.01560 iter_time = 3.53453
# 170: RMSE(train) = 0.99928 RMSE(test) = 1.01238 iter_time = 3.48986
# 180: RMSE(train) = 0.99617 RMSE(test) = 1.00957 iter_time = 3.53743
# 190: RMSE(train) = 0.99354 RMSE(test) = 1.00723 iter_time = 3.51094
# 200: RMSE(train) = 0.99118 RMSE(test) = 1.00520 iter_time = 3.50181
# 210: RMSE(train) = 0.98920 RMSE(test) = 1.00339 iter_time = 3.54503
# 220: RMSE(train) = 0.98698 RMSE(test) = 1.00137 iter_time = 3.40167
# 230: RMSE(train) = 0.98506 RMSE(test) = 0.99978 iter_time = 3.52381
# 240: RMSE(train) = 0.98286 RMSE(test) = 0.99806 iter_time = 3.47992
# 250: RMSE(train) = 0.98037 RMSE(test) = 0.99589 iter_time = 3.51532
# 260: RMSE(train) = 0.97742 RMSE(test) = 0.99355 iter_time = 3.52584
# 270: RMSE(train) = 0.97398 RMSE(test) = 0.99068 iter_time = 3.53453
# 280: RMSE(train) = 0.96975 RMSE(test) = 0.98741 iter_time = 3.52963
# 290: RMSE(train) = 0.96525 RMSE(test) = 0.98382 iter_time = 3.52712
# 300: RMSE(train) = 0.96059 RMSE(test) = 0.98036 iter_time = 3.53098
# 310: RMSE(train) = 0.95627 RMSE(test) = 0.97727 iter_time = 3.51331
# 320: RMSE(train) = 0.95256 RMSE(test) = 0.97455 iter_time = 3.52619
# 330: RMSE(train) = 0.94921 RMSE(test) = 0.97208 iter_time = 3.48836
# 340: RMSE(train) = 0.94608 RMSE(test) = 0.96980 iter_time = 3.53293
# 350: RMSE(train) = 0.94330 RMSE(test) = 0.96767 iter_time = 3.54479
# 360: RMSE(train) = 0.94082 RMSE(test) = 0.96590 iter_time = 3.52705
# 370: RMSE(train) = 0.93849 RMSE(test) = 0.96406 iter_time = 3.53482
# 380: RMSE(train) = 0.93610 RMSE(test) = 0.96239 iter_time = 3.47550
# 390: RMSE(train) = 0.93387 RMSE(test) = 0.96070 iter_time = 3.52816
# 400: RMSE(train) = 0.93148 RMSE(test) = 0.95902 iter_time = 3.54342
# 410: RMSE(train) = 0.92922 RMSE(test) = 0.95746 iter_time = 3.54573
# 420: RMSE(train) = 0.92697 RMSE(test) = 0.95585 iter_time = 3.48756
# 430: RMSE(train) = 0.92457 RMSE(test) = 0.95420 iter_time = 3.53351
# 440: RMSE(train) = 0.92217 RMSE(test) = 0.95269 iter_time = 3.65981
# 450: RMSE(train) = 0.91977 RMSE(test) = 0.95127 iter_time = 3.46604
# 460: RMSE(train) = 0.91743 RMSE(test) = 0.94983 iter_time = 3.53798
# 470: RMSE(train) = 0.91522 RMSE(test) = 0.94842 iter_time = 3.52509
# 480: RMSE(train) = 0.91311 RMSE(test) = 0.94727 iter_time = 3.52446
# 490: RMSE(train) = 0.91121 RMSE(test) = 0.94622 iter_time = 3.52422
# 500: RMSE(train) = 0.90954 RMSE(test) = 0.94524 iter_time = 3.65649
# 510: RMSE(train) = 0.90764 RMSE(test) = 0.94416 iter_time = 3.48971
# 520: RMSE(train) = 0.90601 RMSE(test) = 0.94303 iter_time = 3.52574
# 530: RMSE(train) = 0.90442 RMSE(test) = 0.94199 iter_time = 3.53532
# 540: RMSE(train) = 0.90282 RMSE(test) = 0.94108 iter_time = 3.54117
# 550: RMSE(train) = 0.90146 RMSE(test) = 0.94032 iter_time = 3.50739
# 560: RMSE(train) = 0.90009 RMSE(test) = 0.93937 iter_time = 3.55908
# 570: RMSE(train) = 0.89876 RMSE(test) = 0.93827 iter_time = 3.54428
# 580: RMSE(train) = 0.89753 RMSE(test) = 0.93739 iter_time = 3.48406
# 590: RMSE(train) = 0.89633 RMSE(test) = 0.93660 iter_time = 3.56253
# 600: RMSE(train) = 0.89518 RMSE(test) = 0.93576 iter_time = 3.52216
# 610: RMSE(train) = 0.89406 RMSE(test) = 0.93515 iter_time = 3.51985
# 620: RMSE(train) = 0.89303 RMSE(test) = 0.93429 iter_time = 3.50258
# 630: RMSE(train) = 0.89198 RMSE(test) = 0.93346 iter_time = 3.53359
# 640: RMSE(train) = 0.89103 RMSE(test) = 0.93294 iter_time = 3.53152
# 650: RMSE(train) = 0.89011 RMSE(test) = 0.93243 iter_time = 3.49551
# 660: RMSE(train) = 0.88930 RMSE(test) = 0.93165 iter_time = 3.53964
# 670: RMSE(train) = 0.88843 RMSE(test) = 0.93111 iter_time = 3.47753
# 680: RMSE(train) = 0.88757 RMSE(test) = 0.93047 iter_time = 3.53200
# 690: RMSE(train) = 0.88681 RMSE(test) = 0.93000 iter_time = 3.49986
# 700: RMSE(train) = 0.88604 RMSE(test) = 0.92940 iter_time = 3.54672
# 710: RMSE(train) = 0.88534 RMSE(test) = 0.92905 iter_time = 3.54353
# 720: RMSE(train) = 0.88459 RMSE(test) = 0.92853 iter_time = 3.55054
# 730: RMSE(train) = 0.88392 RMSE(test) = 0.92807 iter_time = 3.53607
# 740: RMSE(train) = 0.88323 RMSE(test) = 0.92759 iter_time = 3.48384
# 750: RMSE(train) = 0.88259 RMSE(test) = 0.92722 iter_time = 3.54771
# 760: RMSE(train) = 0.88197 RMSE(test) = 0.92674 iter_time = 3.51956
# 770: RMSE(train) = 0.88141 RMSE(test) = 0.92632 iter_time = 3.54388
# 780: RMSE(train) = 0.88080 RMSE(test) = 0.92587 iter_time = 3.46618
# 790: RMSE(train) = 0.88026 RMSE(test) = 0.92549 iter_time = 3.54799
# 800: RMSE(train) = 0.87969 RMSE(test) = 0.92518 iter_time = 3.52630
# 810: RMSE(train) = 0.87921 RMSE(test) = 0.92480 iter_time = 3.50111
# 820: RMSE(train) = 0.87868 RMSE(test) = 0.92442 iter_time = 3.48506
# 830: RMSE(train) = 0.87828 RMSE(test) = 0.92426 iter_time = 3.55458
# 840: RMSE(train) = 0.87783 RMSE(test) = 0.92384 iter_time = 3.53263
# 850: RMSE(train) = 0.87737 RMSE(test) = 0.92363 iter_time = 3.41223
# 860: RMSE(train) = 0.87698 RMSE(test) = 0.92325 iter_time = 3.52946
# 870: RMSE(train) = 0.87649 RMSE(test) = 0.92292 iter_time = 3.51560
# 880: RMSE(train) = 0.87611 RMSE(test) = 0.92263 iter_time = 3.52674
# 890: RMSE(train) = 0.87573 RMSE(test) = 0.92252 iter_time = 3.45810
# 900: RMSE(train) = 0.87526 RMSE(test) = 0.92235 iter_time = 3.55203
# 910: RMSE(train) = 0.87487 RMSE(test) = 0.92200 iter_time = 3.52872
# 920: RMSE(train) = 0.87452 RMSE(test) = 0.92170 iter_time = 3.53223
# 930: RMSE(train) = 0.87421 RMSE(test) = 0.92168 iter_time = 3.53441
# 940: RMSE(train) = 0.87382 RMSE(test) = 0.92149 iter_time = 3.54986
# 950: RMSE(train) = 0.87342 RMSE(test) = 0.92111 iter_time = 3.51462
# 960: RMSE(train) = 0.87306 RMSE(test) = 0.92092 iter_time = 3.46548
# 970: RMSE(train) = 0.87275 RMSE(test) = 0.92076 iter_time = 3.53346
# 980: RMSE(train) = 0.87245 RMSE(test) = 0.92053 iter_time = 3.52538
# 990: RMSE(train) = 0.87219 RMSE(test) = 0.92020 iter_time = 3.53617
# fold index 3: R2 = 0.2820953493687738
# 0: RMSE(train) = 3.76512 RMSE(test) = 3.76459 iter_time = 3.54107
# 10: RMSE(train) = 3.13894 RMSE(test) = 3.13844 iter_time = 3.53003
# 20: RMSE(train) = 2.63991 RMSE(test) = 2.63945 iter_time = 3.66140
# 30: RMSE(train) = 2.24659 RMSE(test) = 2.24618 iter_time = 3.50159
# 40: RMSE(train) = 1.94001 RMSE(test) = 1.93966 iter_time = 3.53446
# 50: RMSE(train) = 1.70145 RMSE(test) = 1.70129 iter_time = 3.48945
# 60: RMSE(train) = 1.49866 RMSE(test) = 1.49955 iter_time = 3.53100
# 70: RMSE(train) = 1.28995 RMSE(test) = 1.29425 iter_time = 3.51570
# 80: RMSE(train) = 1.15017 RMSE(test) = 1.15829 iter_time = 3.51289
# 90: RMSE(train) = 1.09017 RMSE(test) = 1.10030 iter_time = 3.53471
# 100: RMSE(train) = 1.05786 RMSE(test) = 1.06894 iter_time = 3.51253
# 110: RMSE(train) = 1.03833 RMSE(test) = 1.05020 iter_time = 3.55619
# 120: RMSE(train) = 1.02496 RMSE(test) = 1.03746 iter_time = 3.49200
# 130: RMSE(train) = 1.01568 RMSE(test) = 1.02847 iter_time = 3.55122
# 140: RMSE(train) = 1.00878 RMSE(test) = 1.02200 iter_time = 3.51704
# 150: RMSE(train) = 1.00305 RMSE(test) = 1.01664 iter_time = 3.52067
# 160: RMSE(train) = 0.99868 RMSE(test) = 1.01252 iter_time = 3.51891
# 170: RMSE(train) = 0.99535 RMSE(test) = 1.00936 iter_time = 3.69236
# 180: RMSE(train) = 0.99229 RMSE(test) = 1.00664 iter_time = 3.52558
# 190: RMSE(train) = 0.98971 RMSE(test) = 1.00453 iter_time = 3.49020
# 200: RMSE(train) = 0.98746 RMSE(test) = 1.00243 iter_time = 3.50823
# 210: RMSE(train) = 0.98545 RMSE(test) = 1.00057 iter_time = 3.50773
# 220: RMSE(train) = 0.98358 RMSE(test) = 0.99894 iter_time = 3.53348
# 230: RMSE(train) = 0.98186 RMSE(test) = 0.99738 iter_time = 3.53177
# 240: RMSE(train) = 0.98015 RMSE(test) = 0.99593 iter_time = 3.53612
# 250: RMSE(train) = 0.97846 RMSE(test) = 0.99447 iter_time = 3.53447
# 260: RMSE(train) = 0.97647 RMSE(test) = 0.99276 iter_time = 3.42202
# 270: RMSE(train) = 0.97413 RMSE(test) = 0.99086 iter_time = 3.51894
# 280: RMSE(train) = 0.97131 RMSE(test) = 0.98870 iter_time = 3.52794
# 290: RMSE(train) = 0.96783 RMSE(test) = 0.98596 iter_time = 3.52442
# 300: RMSE(train) = 0.96381 RMSE(test) = 0.98280 iter_time = 3.38610
# 310: RMSE(train) = 0.95926 RMSE(test) = 0.97942 iter_time = 3.53578
# 320: RMSE(train) = 0.95493 RMSE(test) = 0.97604 iter_time = 3.62069
# 330: RMSE(train) = 0.95065 RMSE(test) = 0.97317 iter_time = 3.50009
# 340: RMSE(train) = 0.94689 RMSE(test) = 0.97068 iter_time = 3.50820
# 350: RMSE(train) = 0.94349 RMSE(test) = 0.96844 iter_time = 3.39959
# 710: RMSE(train) = 0.88268 RMSE(test) = 0.92705 iter_time = 3.49466
# 720: RMSE(train) = 0.88206 RMSE(test) = 0.92643 iter_time = 3.52288
# 730: RMSE(train) = 0.88149 RMSE(test) = 0.92605 iter_time = 3.52787
# 740: RMSE(train) = 0.88094 RMSE(test) = 0.92573 iter_time = 3.52303
# 750: RMSE(train) = 0.88044 RMSE(test) = 0.92542 iter_time = 3.50912
# 760: RMSE(train) = 0.87986 RMSE(test) = 0.92505 iter_time = 3.51474
# 770: RMSE(train) = 0.87936 RMSE(test) = 0.92473 iter_time = 3.64890
# 780: RMSE(train) = 0.87890 RMSE(test) = 0.92449 iter_time = 3.48299
# 790: RMSE(train) = 0.87840 RMSE(test) = 0.92426 iter_time = 3.52170
# 800: RMSE(train) = 0.87797 RMSE(test) = 0.92389 iter_time = 3.51048
# 810: RMSE(train) = 0.87753 RMSE(test) = 0.92366 iter_time = 3.52249
# 820: RMSE(train) = 0.87705 RMSE(test) = 0.92335 iter_time = 3.49569
# 830: RMSE(train) = 0.87664 RMSE(test) = 0.92305 iter_time = 3.51843
# 840: RMSE(train) = 0.87620 RMSE(test) = 0.92257 iter_time = 3.53189
# 850: RMSE(train) = 0.87576 RMSE(test) = 0.92237 iter_time = 3.51982
# 860: RMSE(train) = 0.87535 RMSE(test) = 0.92208 iter_time = 3.46344
# 870: RMSE(train) = 0.87500 RMSE(test) = 0.92192 iter_time = 3.53980
# 880: RMSE(train) = 0.87465 RMSE(test) = 0.92173 iter_time = 3.52422
# 890: RMSE(train) = 0.87422 RMSE(test) = 0.92144 iter_time = 3.52869
# 900: RMSE(train) = 0.87386 RMSE(test) = 0.92125 iter_time = 3.52146
# 910: RMSE(train) = 0.87353 RMSE(test) = 0.92107 iter_time = 3.49465
# 920: RMSE(train) = 0.87322 RMSE(test) = 0.92085 iter_time = 3.60635
# 930: RMSE(train) = 0.87288 RMSE(test) = 0.92069 iter_time = 3.47026
# 940: RMSE(train) = 0.87259 RMSE(test) = 0.92051 iter_time = 3.54898
# 950: RMSE(train) = 0.87228 RMSE(test) = 0.92025 iter_time = 3.49613
# 960: RMSE(train) = 0.87196 RMSE(test) = 0.92009 iter_time = 3.54469
# 970: RMSE(train) = 0.87164 RMSE(test) = 0.91986 iter_time = 3.54811
# 980: RMSE(train) = 0.87138 RMSE(test) = 0.91970 iter_time = 3.54107
# 990: RMSE(train) = 0.87104 RMSE(test) = 0.91974 iter_time = 3.54176
# fold index 4: R2 = 0.28361550318423523
# [0.2631461910207641,
#  0.28000941266604396,
#  0.2819908433318903,
#  0.2820953493687738,
#  0.28361550318423523]

# %%
print(time.time())
# Out:
# 1577379853.03

# %%
print(time.time())
# Out:
# 1577379854.13

# %%
RMSE(y, np.mean(y) * np.ones(shape=y.shape))
# Out:
# 1.0394660359078236

# %%
1 - (0.3064003742476023) **2 / (1.0394660359078236)**2
# Out:
# 0.9131123650977964
